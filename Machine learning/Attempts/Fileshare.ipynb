# %%
# !pip install azure-eventhub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 150 kB 5.3 MB/s
# ...
#      |████████████████████████████████| 172 kB 42.2 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 42.3 MB/s
# ...

# %%
from azure.eventhub.aio import EventHubProducerClient
from azure.eventhub import EventData

# %%
eventhub=EventHubProducerClient.from_connection_string(conn_str='Endpoint=sb://labuser13eventhub.servicebus.windows.net/;SharedAccessKeyName=me;SharedAccessKey=bPgScYc8aoNHE1pIbJ8XfmU6ubWONrd2Bsm9HkvdxHs=;EntityPath=event13')

# %%
import time
from datetime import datetime

i=0

while(1):
  message='time:'+str(datetime.now())
  eventhub.send_event(EventData(message))

  i+=1
  if i%10==0:
    print('message {} sending...'.format(i))

  time.sleep(1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: coroutine 'EventHubProducerClient.send_event' was never awaited
#
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-997933aab245> in <module>
#      12     print('message {} sending...'.format(i))
#      13
# ---> 14   time.sleep(1)
#
# KeyboardInterrupt:
