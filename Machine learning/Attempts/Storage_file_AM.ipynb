# %%
# !pip install azure-storage-file
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 47 kB 3.7 MB/s
# ...
#      |████████████████████████████████| 4.1 MB 11.2 MB/s
# ...

# %%
#connecting to the fileshare
from azure.storage.file import FileService
file_service=FileService(account_name='labuser13storage1',
                         account_key='Ygy7AT2ehRRCGg64A1+Ttmz2tP09m0MlIxsoS91eaupwJzurcxuHgTYr6+sh+9S2tRqnSvLU0iiJ+AStu1aFag==')

# %%
#creating sharing folder 'myshare'
file_service.create_share('myshare')
# Out:
# True

# %%
#creeating sample directory in 'myshare'
file_service.create_directory('myshare','sampledir')
# Out:
# True

# %%
#IU.jpg copying to the myfile folder

from azure.storage.file import ContentSettings

file_service.create_file_from_path('myshare',
                                   None,
                                   'myfile',
                                   'IU.jpg',
                                   content_settings=ContentSettings(content_type='image/jpg'))

# %%
#getting the file list from the shared folder
generator=file_service.list_directories_and_files('myshare')
for file_or_dir in generator:
  print(file_or_dir.name)
# Out:
# myfile
# sampledir

# %%
#acclaiming IU.jpg as out-IU.jpg to myfile

file_service.get_file_to_path('myshare',None,'myfile','out-IU.jpg')

# %%
#creating a new snapshot 

metadata={'foo':'bar'}
snapshot=file_service.snapshot_share('myshare',metadata=metadata)

# %%
# viewing the exisiting snapshot list 
shares = list(file_service.list_shares(include_snapshots=True))

for s in shares:
  print(s.snapshot)
# Out:
# 2022-11-08T00:24:16.0000000Z
# 2022-11-08T00:29:48.0000000Z
# None

# %%
#retrieve the file of the snapshot and directory list 
directories_and_files = list(
    file_service.list_directories_and_files('myshare', snapshot='2022-11-08T00:29:48.0000000Z'))

# %%
#printing the file and directory name
directories_and_files
for file_or_dir in generator:
    print(file_or_dir.name)
# Out:
# myfile
# sampledir

# %%
#deleting snapshot
file_service.delete_share('myshare', snapshot='2022-11-08T00:29:48.0000000Z')
# Out:
# True

# %%
#deleting file within the sharefolder
file_service.delete_file('myshare', None, 'myfile')

# %%
#deleting the shared folder
file_service.delete_share('myshare')
# Out:
# True
